# %% [markdown]
# # Import Libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('/Users/wiltonngo/Apartment Rentals/ Data/Prepared Data/app.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                State  Service Charge  \
# 0           0  Nordrhein_Westfalen          245.00
# 1           1      Rheinland_Pfalz          134.00
# 2           2              Sachsen          255.00
# 3           3              Sachsen           58.15
# 4           4               Bremen          138.00
#
#                      Heating Type Telekom-Tv Offer  Newly Construction  \
# 0                 central_heating    ONE_YEAR_FREE               False
# 1  self_contained_central_heating    ONE_YEAR_FREE               False
# 2                   floor_heating    ONE_YEAR_FREE                True
# 3                district_heating    ONE_YEAR_FREE               False
# 4  self_contained_central_heating              NaN               False
#
#    Balcony  Picture_count  Price_Trend  Telekom Upload Speed  ...  Base Rent  \
# 0    False              6         4.62                  10.0  ...      595.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            268850 non-null  int64
#  1   State                 268850 non-null  object
#  2   Service Charge        261941 non-null  float64
#  3   Heating Type          223994 non-null  object
#  4   Telekom-Tv Offer      236231 non-null  object
#  5   Newly Construction    268850 non-null  bool
#  6   Balcony               268850 non-null  bool
#  7   Picture_count         268850 non-null  int64
#  8   Price_Trend           267018 non-null  float64
#  9   Telekom Upload Speed  235492 non-null  float64
#  10  Total Rent            228333 non-null  float64
#  11  Year Constructed      211805 non-null  float64
#  12  Scout ID              268850 non-null  int64
#  13  Kitchen               268850 non-null  bool
# ...

# %% [markdown]
# # Remove Column

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.drop(columns=['Total Rent.1'],inplace=True)

# %%
#Print the first 5 rows
df.head()
# Out:
#                  State  Service Charge                    Heating Type  \
# 0  Nordrhein_Westfalen          245.00                 central_heating
# 1      Rheinland_Pfalz          134.00  self_contained_central_heating
# 2              Sachsen          255.00                   floor_heating
# 3              Sachsen           58.15                district_heating
# 4               Bremen          138.00  self_contained_central_heating
#
#   Telekom-Tv Offer  Newly Construction  Balcony  Picture_count  Price_Trend  \
# 0    ONE_YEAR_FREE               False    False              6         4.62
# 1    ONE_YEAR_FREE               False     True              8         3.47
# 2    ONE_YEAR_FREE                True     True              8         2.72
# 3    ONE_YEAR_FREE               False     True              9         1.53
# 4              NaN               False     True             19         2.46
#
#    Telekom Upload Speed  Total Rent  ...  Cellar  Base Rent  Living Space  \
# ...

# %%
df.drop(columns=['State','Heating Type','Newly Construction','Balcony','date','Garden','Type Of Flat','Lift','Pets Allowed','Cellar','Kitchen'],inplace=True)

# %%
# Romms
df.drop([5206,17897,18961,35033,63453,77343,92451,98055,120251,156291,163563,174132,191228,205003,240390,263045],inplace=True)

# %%
# Total Rent
df.drop([8406,23490,79903,109047,239533,260259],inplace= True)

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                       Service Charge  Picture_count  Price_Trend  \
# Service Charge              1.000000       0.061560     0.063734
# Picture_count               0.061560       1.000000     0.113927
# Price_Trend                 0.063734       0.113927     1.000000
# Telekom Upload Speed        0.010681       0.008107     0.034376
# Total Rent                  0.179844       0.267881     0.392244
# Year Constructed            0.032163       0.008952     0.133511
# Scout ID                    0.015433       0.005909     0.034780
# Base Rent                   0.236235       0.004648     0.012213
# Living Space                0.076174       0.034484     0.022749
# Rooms                       0.053439       0.072060     0.013457
# Floor                       0.002057      -0.001085     0.011917
#
#                       Telekom Upload Speed  Total Rent  Year Constructed  \
# Service Charge                    0.010681    0.179844          0.032163
# ...

# %%
# Creating a correlation heatmap
# Creating a correlation heatmap

corr_figure = plt.figure(figsize=(8, 8)) # Size of the figure
plt.matshow(df.corr(), fignum=corr_figure.number) # Type of plot, correlation heatmap
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=90) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
corr_cb = plt.colorbar() # add a colorbar
corr_cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,12))
#Create the correlation Heatmap using seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df.corr(), annot = True, ax = ax)# The `annot` argument allows the plot to place the correlation coefficent to the hatmap

# %%
df.drop(columns=['Base Rent','Scout ID','Year Constructed','Telekom Upload Speed'],inplace=True)

# %% [markdown]
# So based on the heatmap
#
# ### Service Rent :
# - weak relationship with Base Rent
# ### Newly Construction:
# - Weak Relationship with Total Rent,Lift and Yearly Constructed
# ### Balcony:
# - Weak Relationship with Total Rent,lift and Yearly Constructed
# ### Picture_count:
# - Weak Relationship with Total Rent
# ### Price_Trend:
# - Moderate Relationship with Total Rent
# - Weak Relationship Lift and Kitchen
# ### Year-_constructed:
# - Weak relationship Balcony and Newly Construction
# ### Base Rent:
# - Weak relationship with Service Charge and Year Constructed
# ### Lift:
# - Weak relationship with Total Rent and Year constructed,Price trend,Balcony New Construction

# %% [markdown]
# # ScatterPlots

# %% [markdown]
# ### Some variables have a strong Relationship bewteen the variables, we have to find if the correlation is linear.If it is linear it means it will have an impact to each other.

# %% [markdown]
# ## Service Rent and Base Rent

# %%
### Look at the correlation bewteen service rent and Base rent
scatter_Ser_Bas = sns.lmplot(x = 'Service Charge', y = 'Base Rent', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Price_Trend', y = 'Kitchen', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Newly Construction', y = 'Lift', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Year Constructed', y = 'Balcony', data = df)

# %%
scatter_Ser_bas = sns.lmplot(x = 'Living Space', y = 'Total Rent', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Year Constructed', y = 'Lift', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Total Rent', y = 'Rooms', data = df)

# %% [markdown]
# ### The Total Rent and Rooms scatterplot show us that the more rooms you have the more rent. Also show us there outliers for rooms theres no possiblity of having 200+ Rooms

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Total Rent', y = 'Lift', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Total Rent', y = 'Kitchen', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Total Rent', y = 'Balcony', data = df)

# %%
scatter_Ser_Bas = sns.lmplot(x = 'Total Rent', y = 'Picture_count', data = df)

# %% [markdown]
# ### Total Rent and Picture_count allow us to see the more picture you take of the house the more exposure it gives us to see the place that their selling

# %%
df[df['Rooms'] >25]
# Out:
#                       State  Service Charge                    Heating Type  \
# 36872     Baden_Württemberg           250.0                 central_heating
# 103615              Sachsen           140.0  self_contained_central_heating
# 134862  Nordrhein_Westfalen            85.0                 central_heating
# 185115    Baden_Württemberg           110.0                 central_heating
#
#        Telekom-Tv Offer  Newly Construction  Balcony  Picture_count  \
# 36872     ONE_YEAR_FREE               False     True             11
# 103615    ONE_YEAR_FREE               False    False              3
# 134862    ONE_YEAR_FREE               False    False              9
# 185115    ONE_YEAR_FREE               False    False              0
#
#         Price_Trend  Telekom Upload Speed  Total Rent  ...  Cellar  Base Rent  \
# 36872          7.21                  10.0         NaN  ...    True     1100.0
# 103615         0.43                   2.4         NaN  ...    True      282.0
# ...

# %%
df.drop([36872,103615,134862,185115],inplace=True)

# %%
# Pair Plots

# %%
# Keep only the variables you want to use in the pair plot
pair = df[['Total Rent','Service Charge','Year Constructed','Picture_count','Price_Trend','Rooms']]

# %%
g = sns.pairplot(pair)

# %%
# Total Rent and Rooms is the best Visual

# %%
# Cateogorical Plot

# %%
#Use a histogram to visualize the distribution of the variables. 
#This way, you can determine sensible categories for the ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['Total Rent'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='Total Rent', ylabel='Count'>

# %%
df.dropna(subset = ['Total Rent'],inplace = True)

# %%
### According to the Histogram, most of the people rent fall under 800

# %%
I will create categories following this categories
### if <=600 = Cheapest
### if >600 and <=900 = Medium
### if > 900 Expensive

# %%
# Create the first Category
df.loc[df['Total Rent'] <= 600,'Cost_Of_living'] = 'Cheapest'

# %%
# Create the second Category
df.loc[(df['Total Rent'] > 600) &(df['Total Rent'] <= 900),'Cost_Of_living'] = 'Median'

# %%
df.loc[df['Total Rent'] > 900, 'Cost_Of_living'] = 'Expensive'

# %%
df['Total Rent'].mean()
# Out:
# 814.9408274095072

# %%
df.head()
# Out:
#                  State  Service Charge                    Heating Type  \
# 0  Nordrhein_Westfalen           245.0                 central_heating
# 2              Sachsen           255.0                   floor_heating
# 4               Bremen           138.0  self_contained_central_heating
# 6              Sachsen            70.0  self_contained_central_heating
# 7               Bremen            88.0                 central_heating
#
#   Telekom-Tv Offer  Newly Construction  Balcony  Picture_count  Price_Trend  \
# 0    ONE_YEAR_FREE               False    False              6         4.62
# 2    ONE_YEAR_FREE                True     True              8         2.72
# 4              NaN               False     True             19         2.46
# 6    ONE_YEAR_FREE               False    False              9         1.01
# 7    ONE_YEAR_FREE               False     True              5         1.89
#
#    Telekom Upload Speed  Total Rent  ...  Base Rent  Living Space  \
# ...

# %%
# Check the Requencies for the Cost of Living column
df['Cost_Of_living'].value_counts()
# Out:
# Cheapest     103304
# Expensive     66992
# Median        58019
# Name: Cost_Of_living, dtype: int64

# %% [markdown]
# ### This reflects the distriubtion seen in thie histogram

# %%
# Create a categorical plot in seaborn using the categories created above

sns.set(style="ticks")
g = sns.catplot(x="Rooms", y="Total Rent", hue="Cost_Of_living", data=df)
g.set_xticklabels(rotation=90)

# %% [markdown]
# Its interesting to see that the more rooms that the more expensive the Rent it is. I'am to curious to see how many mansions or houses are the most expensive. where the apartments probably have only couple of rooms

# %%
df['Rooms'].value_counts()
# Out:
# 3.00     76985
# 2.00     76944
# 1.00     24057
# 4.00     23233
# 2.50      8235
# 3.50      7504
# 5.00      4712
# 1.50      3002
# 4.50      1676
# 6.00      1067
# 5.50       277
# 7.00       270
# 8.00        99
# 2.10        67
# 6.50        49
# 2.20        31
# 9.00        25
# 10.00       19
# 7.50        15
# 11.00        8
# 15.00        5
# 1.10         5
# 12.00        5
# 8.50         3
# 23.00        3
# 13.00        2
# 3.10         2
# 25.00        1
# 3.80         1
# 22.00        1
# 3.40         1
# 1.20         1
# 21.00        1
# 2.90         1
# 4.20         1
# 2.65         1
# 18.00        1
# 14.00        1
# 2.30         1
# 2.70         1
# 16.00        1
# 1.25         1
# Name: Rooms, dtype: int64

# %%
### Its interest to see that

# %%
df[df['Rooms']>10]
# Out:
#                          State  Service Charge  \
# 14123                   Hessen          1400.0
# 21472          Rheinland_Pfalz           200.0
# 52202                Thüringen           120.0
# 64109                  Sachsen           250.0
# 70070      Nordrhein_Westfalen           100.0
# 73129                  Sachsen           800.0
# 88504   Mecklenburg_Vorpommern            87.0
# 93113                   Bremen           130.0
# 97475                   Bayern             NaN
# 106630          Sachsen_Anhalt            60.0
# 119135                  Berlin          1000.0
# 123659     Nordrhein_Westfalen           100.0
# 127873                  Hessen           500.0
# 148017     Nordrhein_Westfalen           660.0
# 149520                 Sachsen           645.0
# 152681     Nordrhein_Westfalen           155.0
# 159423         Rheinland_Pfalz           200.0
# 163703           Niedersachsen             NaN
# 177289                  Berlin          3800.0
# ...

# %%
# Revist Questions

# %% [markdown]
# ## Questions Answered
#  - ### What kind of features do they want in the house (ex: Garden,Cellar, etc)?
# ### It appears when people looking for the house they are looking for a Balcony, Kithcen and garden. The more features they have the more expensive the rent

# %% [markdown]
# - ### How much per Rent are people willing to pay

# %% [markdown]
# ### The most pouplar homes are looking for Cheap homes which up to $600. That people want to rent homes that are cheaper which are apartmens. The most expensive homes are homes that have more advanced features that is included.

# %%
Ones to look into Furthur

# %% [markdown]
#  - Which City in Germany in the most popular to live in like the Geographical Location?

# %% [markdown]
#  - What type of place do they like to live in like apartments,massions or house?

# %% [markdown]
#  - How much the living space is needed to live?

# %% [markdown]
#  - How many floors do people to prefer to live?

# %% [markdown]
# # Visualizations for Exploring Relatoinships

# %%
# Bar chart
df['Type Of Flat'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Bar Chart for how many floors they want to live
df['Floor'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# What is the most popular Destination to live
df['State'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Hypothesis
# ### The Total Rent for Apartments is the cheapest place to live in
# ###  The most popular state is where people want to live in the most and it is the most expensive.

# %%
df.to_csv(r'/Users/wiltonngo/Apartment Rentals/ Data/Prepared Data/app2.csv')
