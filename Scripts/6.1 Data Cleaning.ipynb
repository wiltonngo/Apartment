# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('/Users/wiltonngo/Downloads/immo_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df = pd.read_csv('/Users/wiltonngo/Downloads/immo_data2.csv')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# 1  ONE_YEAR_FREE                       NaN       False     True             8
# 2  ONE_YEAR_FREE                      10.0        True     True             8
# 3  ONE_YEAR_FREE                       NaN       False     True             9
# 4            NaN                       NaN       False     True            19
#
#    pricetrend  telekomUploadSpeed  ...               regio2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %% [markdown]
# # Drop Uncessary Columns

# %%
df.drop(columns=['electricityKwhPrice','electricityBasePrice','lastRefurbish','energyEfficiencyClass','heatingCosts','facilities','description','livingSpaceRange','noRoomsRange','numberOfFloors','thermalChar','geo_plz','streetPlain','street','interiorQual','condition','geo_krs','geo_plz','firingTypes','noParkSpaces','regio2','regio3'],inplace=True)

# %%
df.head()
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# 1  ONE_YEAR_FREE                       NaN       False     True             8
# 2  ONE_YEAR_FREE                      10.0        True     True             8
# 3  ONE_YEAR_FREE                       NaN       False     True             9
# 4            NaN                       NaN       False     True            19
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df.drop(columns=['telekomHybridUploadSpeed','geo_bln','houseNumber'],inplace=True)

# %%
df.drop(columns=['yearConstructedRange'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   regio1              268850 non-null  object
#  1   serviceCharge       261941 non-null  float64
#  2   heatingType         223994 non-null  object
#  3   telekomTvOffer      236231 non-null  object
#  4   newlyConst          268850 non-null  bool
#  5   balcony             268850 non-null  bool
#  6   picturecount        268850 non-null  int64
#  7   pricetrend          267018 non-null  float64
#  8   telekomUploadSpeed  235492 non-null  float64
#  9   totalRent           228333 non-null  float64
#  10  yearConstructed     211805 non-null  float64
#  11  scoutId             268850 non-null  int64
#  12  hasKitchen          268850 non-null  bool
#  13  cellar              268850 non-null  bool
#  14  baseRent            268850 non-null  float64
# ...

# %% [markdown]
# # Rename Columns

# %%
df.rename(columns={'regio1':'State','serviceCharge':'Service Charge','heatingType': 'Heating Type','telekomTvOffer':'Telekom-Tv Offer','newlyConst':'Newly Construction','balcony':'Balcony','picturecount':'Picture_count','pricetrend':'Price_Trend','telekomUploadSpeed':'Telekom Upload Speed','totalRent':'Total Rent','yearConstructed':'Year Constructed','scoutId':'Scout ID','hasKitchen':'Kitchen','cellar':'Cellar','baseRent':'Base Rent','livingSpace':'Living Space','petsAllowed':'Pets Allowed','lift':'Lift','baseRentRange':'Total Rent','noRooms':'Rooms','floor':'Floor','garden':'Garden','typeOfFlat':'Type Of Flat'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   State                 268850 non-null  object
#  1   Service Charge        261941 non-null  float64
#  2   Heating Type          223994 non-null  object
#  3   Telekom-Tv Offer      236231 non-null  object
#  4   Newly Construction    268850 non-null  bool
#  5   Balcony               268850 non-null  bool
#  6   Picture_count         268850 non-null  int64
#  7   Price_Trend           267018 non-null  float64
#  8   Telekom Upload Speed  235492 non-null  float64
#  9   Total Rent            228333 non-null  float64
#  10  Year Constructed      211805 non-null  float64
#  11  Scout ID              268850 non-null  int64
#  12  Kitchen               268850 non-null  bool
#  13  Cellar                268850 non-null  bool
# ...

# %% [markdown]
# # Check if there is Null Values

# %%
df.isnull().sum()
# Out:
# State                        0
# Service Charge            6909
# Heating Type             44856
# Telekom-Tv Offer         32619
# Newly Construction           0
# Balcony                      0
# Picture_count                0
# Price_Trend               1832
# Telekom Upload Speed     33358
# Total Rent               40517
# Year Constructed         57045
# Scout ID                     0
# Kitchen                      0
# Cellar                       0
# Base Rent                    0
# Living Space                 0
# Pets Allowed            114573
# Lift                         0
# Total Rent                   0
# Type Of Flat             36614
# Rooms                        0
# Floor                    51309
# Garden                       0
# date                         0
# dtype: int64

# %%
df.head()
# Out:
#                  State  Service Charge                    Heating Type  \
# 0  Nordrhein_Westfalen          245.00                 central_heating
# 1      Rheinland_Pfalz          134.00  self_contained_central_heating
# 2              Sachsen          255.00                   floor_heating
# 3              Sachsen           58.15                district_heating
# 4               Bremen          138.00  self_contained_central_heating
#
#   Telekom-Tv Offer  Newly Construction  Balcony  Picture_count  Price_Trend  \
# 0    ONE_YEAR_FREE               False    False              6         4.62
# 1    ONE_YEAR_FREE               False     True              8         3.47
# 2    ONE_YEAR_FREE                True     True              8         2.72
# 3    ONE_YEAR_FREE               False     True              9         1.53
# 4              NaN               False     True             19         2.46
#
#    Telekom Upload Speed  Total Rent  ...  Base Rent  Living Space  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66230 entries, 8 to 268847
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 66230 non-null  object
#  1   Service Charge        66230 non-null  float64
#  2   Heating Type          66230 non-null  object
#  3   Telekom-Tv Offer      66230 non-null  object
#  4   Newly Construction    66230 non-null  bool
#  5   Balcony               66230 non-null  bool
#  6   Picture_count         66230 non-null  int64
#  7   Price_Trend           66230 non-null  float64
#  8   Telekom Upload Speed  66230 non-null  float64
#  9   Total Rent            66230 non-null  float64
#  10  Year Constructed      66230 non-null  float64
#  11  Scout ID              66230 non-null  int64
#  12  Kitchen               66230 non-null  bool
#  13  Cellar                66230 non-null  bool
#  14  Base Rent             66230 non-null  float64
# ...

# %%
df.to_csv(r'/Users/wiltonngo/Apartment Rentals/ Data/Prepared Data/app.csv')
